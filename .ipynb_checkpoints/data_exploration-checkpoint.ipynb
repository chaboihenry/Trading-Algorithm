# %%
import pandas as pd
import s3fs

# defintion of S3 path to appl parqueet file
s3_file_path = 's3://risklabai-models/AAPL/parquet/ticks.parquet'
# read parquet file directly into a pandas dataframe
df_appl = pd.read_parquet(s3_file_path)

# %%
print(f"---- First 5 rows ----")
print(df_appl.head())
print(f"----- Last 5 rows -----")
print(df_appl.tail())
print(f"\n----- DataFrame info ------")
print(df_appl.info())
# Out:
# ---- First 5 rows ----
#         uid                        timestamp       price  size conditions tape
# 0  43657299 2025-01-21 09:00:00.030563+00:00  227.330002     1      @,T,I    K
# 1  43657300 2025-01-21 09:00:00.030572+00:00  227.330002    50      @,T,I    K
# 2  43657301 2025-01-21 09:00:00.030603+00:00  227.330002     2      @,T,I    K
# 3  43657302 2025-01-21 09:00:00.030669+00:00  227.330002   100        @,T    K
# 4  43657303 2025-01-21 09:00:00.030699+00:00  227.330002   100        @,T    K
# ----- Last 5 rows -----
#                 uid                           timestamp       price  size  \
# 161815211  43657294 2026-01-16 00:59:26.057788590+00:00  258.299988     1
# 161815212  43657295 2026-01-16 00:59:30.506756912+00:00  258.320007     4
# 161815213  43657296 2026-01-16 00:59:33.126373843+00:00  258.269989     1
# 161815214  43657297 2026-01-16 00:59:33.130532326+00:00  258.260010    79
# 161815215  43657298 2026-01-16 00:59:54.922196317+00:00  258.290009     4
#
# ...
